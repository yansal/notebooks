# %%
# %pylab inline
plot(randn(1000), '.')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import datetime
print datetime.datetime.now()
# Out:
# 2015-08-23 00:08:49.565219
